# %%
# %cd /home/afkhabirzyanova_3/jupyterhub_slurm/machamp/
# Out:
# /home/afkhabirzyanova_3/jupyterhub_slurm/machamp

# %%
# %pwd
# Out:
# '/home/afkhabirzyanova_3/jupyterhub_slurm/machamp'

# %%
# !python3 train.py --dataset_configs configs/nlu_kk.json --device 0
# Out:
# /opt/software/python/jupyterhub2/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2024-05-25 01:07:02,328 - INFO - machamp.model.trainer - cmd: train.py --dataset_configs configs/nlu_kk.json --device 0
# 2024-05-25 01:07:02,609 - INFO - machamp.model.trainer - GPU: Tesla V100-SXM2-32GB
# 2024-05-25 01:07:02,609 - INFO - machamp.model.trainer - Torch version: 2.3.0+cu121
# 2024-05-25 01:07:02,609 - INFO - machamp.model.trainer - Transformers version: 4.41.1
# 2024-05-25 01:07:02,626 - INFO - machamp.model.trainer - MaChAmp git version 9f5a6ce48fcebed353956f28de59d9d99098f073
# 2024-05-25 01:07:04,848 - INFO - machamp.data.machamp_dataset - Reading /home/afkhabirzyanova_3/jupyterhub_slurm/machamp/data/xSID-tat/kk.projectedTrain.conll...
# ...

# %%
# %mkdir predictions_kk

# %%
# %pwd
# Out:
# '/home/afkhabirzyanova_3/jupyterhub_slurm/machamp'

# %%
# !python3 predict.py logs/nlu_kk/2024.05.23_15.45.19/model_10.pt data/xSID-tat/final_not_full_tat.test.conll predictions_kk/nlu_kk.xsid.out --device 0
# Out:
# /opt/software/python/jupyterhub2/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2024-05-23 16:33:21,392 - INFO - __main__ - cmd: predict.py logs/nlu_kk/2024.05.23_15.45.19/model_10.pt data/xSID-tat/final_not_full_tat.test.conll predictions_kk/nlu_kk.xsid.out --device 0
#
# 2024-05-23 16:33:21,393 - INFO - __main__ - loading model...
# 2024-05-23 16:33:22,922 - INFO - __main__ - predicting on data/xSID-tat/final_not_full_tat.test.conll, saving on predictions_kk/nlu_kk.xsid.out
# 2024-05-23 16:33:23,511 - INFO - machamp.data.machamp_dataset - Reading data/xSID-tat/final_not_full_tat.test.conll...
# 2024-05-23 16:33:24,042 - INFO - machamp.readers.read_sequence - Stats NLU (data/xSID-tat/final_not_full_tat.test.conll):
# ...
