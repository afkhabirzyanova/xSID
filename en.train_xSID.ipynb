# %% [markdown]
# ## Machamp

# %%
# !git clone https://github.com/machamp-nlp/machamp.git
# Out:
# Cloning into 'machamp'...
# remote: Enumerating objects: 1912, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 1912 (delta 93), reused 95 (delta 87), pack-reused 1789
# Receiving objects: 100% (1912/1912), 1.71 MiB | 573.00 KiB/s, done.
# Resolving deltas: 100% (1269/1269), done.

# %%
# %cd machamp/
# Out:
# /Users/alsu/Desktop/Введение в машинное обучение/machamp
# /opt/anaconda3/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip3 install --user -r requirements.txt
# Out:
# Collecting transformers>=4.0.0 (from -r requirements.txt (line 4))
#   Downloading transformers-4.41.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 427.3 kB/s eta 0:00:00a 0:00:01
# Collecting torch>=1.3.0 (from -r requirements.txt (line 5))
#   Downloading torch-2.3.0-cp311-none-macosx_11_0_arm64.whl.metadata (26 kB)
# Collecting sentencepiece (from -r requirements.txt (line 6))
#   Downloading sentencepiece-0.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting jsonnet (from -r requirements.txt (line 7))
#   Downloading jsonnet-0.20.0.tar.gz (594 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.2/594.2 kB 607.7 kB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (4.65.0)
# Collecting uniplot (from -r requirements.txt (line 9))
#   Downloading uniplot-0.12.7-py3-none-any.whl.metadata (16 kB)
# Collecting networkx==2.5 (from -r requirements.txt (line 10))
#   Downloading networkx-2.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: decorator>=4.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from networkx==2.5->-r requirements.txt (line 10)) (5.1.1)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from transformers>=4.0.0->-r requirements.txt (line 4)) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.23.0 (from transformers>=4.0.0->-r requirements.txt (line 4))
#   Downloading huggingface_hub-0.23.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.11/site-packages (from transformers>=4.0.0->-r requirements.txt (line 4)) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from transformers>=4.0.0->-r requirements.txt (line 4)) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.11/site-packages (from transformers>=4.0.0->-r requirements.txt (line 4)) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers>=4.0.0->-r requirements.txt (line 4))
#   Downloading regex-2024.5.15-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 161.8 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (from transformers>=4.0.0->-r requirements.txt (line 4)) (2.31.0)
# Collecting tokenizers<0.20,>=0.19 (from transformers>=4.0.0->-r requirements.txt (line 4))
#   Downloading tokenizers-0.19.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers>=4.0.0->-r requirements.txt (line 4))
#   Downloading safetensors-0.4.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.3.0->-r requirements.txt (line 5)) (4.9.0)
# Collecting sympy (from torch>=1.3.0->-r requirements.txt (line 5))
#   Downloading sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.3.0->-r requirements.txt (line 5)) (3.1.3)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.3.0->-r requirements.txt (line 5)) (2023.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.3.0->-r requirements.txt (line 5)) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests->transformers>=4.0.0->-r requirements.txt (line 4)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests->transformers>=4.0.0->-r requirements.txt (line 4)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests->transformers>=4.0.0->-r requirements.txt (line 4)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests->transformers>=4.0.0->-r requirements.txt (line 4)) (2024.2.2)
# Collecting mpmath>=0.19 (from sympy->torch>=1.3.0->-r requirements.txt (line 5))
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading networkx-2.5-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 430.5 kB/s eta 0:00:0000:0100:01
# Downloading transformers-4.41.0-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 381.7 kB/s eta 0:00:0000:0100:01
# Downloading torch-2.3.0-cp311-none-macosx_11_0_arm64.whl (61.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 MB 1.5 MB/s eta 0:00:0000:0100:010m
# Downloading sentencepiece-0.2.0-cp311-cp311-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 796.3 kB/s eta 0:00:0000:0100:01
# Downloading uniplot-0.12.7-py3-none-any.whl (28 kB)
# Downloading huggingface_hub-0.23.1-py3-none-any.whl (401 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.3/401.3 kB 1.6 MB/s eta 0:00:0000:0100:01
# Downloading regex-2024.5.15-cp311-cp311-macosx_11_0_arm64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.3/278.3 kB 1.1 MB/s eta 0:00:0000:0100:01
# Downloading safetensors-0.4.3-cp311-cp311-macosx_11_0_arm64.whl (410 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.3/410.3 kB 1.2 MB/s eta 0:00:0000:0100:01
# Downloading tokenizers-0.19.1-cp311-cp311-macosx_11_0_arm64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 1.4 MB/s eta 0:00:0000:0100:01
# Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 893.7 kB/s eta 0:00:0000:0100:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 701.3 kB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: jsonnet
#   Building wheel for jsonnet (setup.py) ... done
#   Created wheel for jsonnet: filename=jsonnet-0.20.0-cp311-cp311-macosx_11_0_arm64.whl size=437318 sha256=e29b95616b4645e14da21a745629ae5530c68e4bf177f665e70cd9a97a609a79
#   Stored in directory: /Users/alsu/Library/Caches/pip/wheels/9e/42/d6/1754654d2a274cc7dc97b5087e49cded863657d63b7d35f676
# Successfully built jsonnet
# Installing collected packages: sentencepiece, mpmath, jsonnet, uniplot, sympy, safetensors, regex, networkx, torch, huggingface-hub, tokenizers, transformers
#   WARNING: The script isympy is installed in '/Users/alsu/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts convert-caffe2-to-onnx, convert-onnx-to-caffe2 and torchrun are installed in '/Users/alsu/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script huggingface-cli is installed in '/Users/alsu/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script transformers-cli is installed in '/Users/alsu/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed huggingface-hub-0.23.1 jsonnet-0.20.0 mpmath-1.3.0 networkx-2.5 regex-2024.5.15 safetensors-0.4.3 sentencepiece-0.2.0 sympy-1.12 tokenizers-0.19.1 torch-2.3.0 transformers-4.41.0 uniplot-0.12.7

# %% [markdown]
# Скачиваем данные xSID, кладем в нужную директорию

# %%
# %mkdir data
# %mkdir data/xSID-0.3/
# %mkdir data/xSID-tat/

# %%
/bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 bin/bash(-c, "$(curl, -fsSL, https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)")
#
# NameError: name 'bash' is not defined

# %%
# !wget -O data/xSID-0.3/en.train.conll https://raw.githubusercontent.com/mainlp/xsid/main/data/xSID/en.train.conll
# !wget -O data/xSID-0.3/en.valid.conll https://raw.githubusercontent.com/mainlp/xsid/main/data/xSID/en.valid.conll
# !wget -O data/xSID-0.3/en.test.conll https://raw.githubusercontent.com/mainlp/xsid/main/data/xSID/en.test.conll
# !wget -O data/xSID-tat/kk.train.conll https://github.com/mainlp/xsid/blob/main/data/xSID/kk.projectedTrain.conll.fixed
# Out:
# --2024-05-22 22:34:45--  https://raw.githubusercontent.com/mainlp/xsid/main/data/xSID/en.train.conll
# Распознаётся raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Подключение к raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... соединение установлено.
# HTTP-запрос отправлен. Ожидание ответа… 200 OK
# Длина: 14643255 (14M) [text/plain]
# Сохранение в: «data/xSID-0.3/en.train.conll»
#
# data/xSID-0.3/en.tr 100%[===================>]  13.96M  2.03MB/s    за 6.4s
#
# 2024-05-22 22:34:52 (2.17 MB/s) - «data/xSID-0.3/en.train.conll» сохранён [14643255/14643255]
#
# --2024-05-22 22:34:52--  https://raw.githubusercontent.com/mainlp/xsid/main/data/xSID/en.valid.conll
# Распознаётся raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Подключение к raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... соединение установлено.
# HTTP-запрос отправлен. Ожидание ответа… 200 OK
# Длина: 101455 (99K) [text/plain]
# Сохранение в: «data/xSID-0.3/en.valid.conll»
#
# data/xSID-0.3/en.va 100%[===================>]  99.08K  --.-KB/s    за 0.06s
#
# 2024-05-22 22:34:52 (1.66 MB/s) - «data/xSID-0.3/en.valid.conll» сохранён [101455/101455]
#
# --2024-05-22 22:34:52--  https://raw.githubusercontent.com/mainlp/xsid/main/data/xSID/en.test.conll
# Распознаётся raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Подключение к raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... соединение установлено.
# HTTP-запрос отправлен. Ожидание ответа… 200 OK
# Длина: 163151 (159K) [text/plain]
# Сохранение в: «data/xSID-0.3/en.test.conll»
#
# data/xSID-0.3/en.te 100%[===================>] 159.33K  --.-KB/s    за 0.1s
#
# 2024-05-22 22:34:52 (1.25 MB/s) - «data/xSID-0.3/en.test.conll» сохранён [163151/163151]

# %%
# %cd /home/afkhabirzyanova_3/jupyterhub_slurm/machamp/
# Out:
# /home/afkhabirzyanova_3/jupyterhub_slurm/machamp

# %%
# !python3 train.py --dataset_configs configs/nlu_en.json --device 0
# Out:
# /opt/software/python/jupyterhub2/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2024-05-24 20:40:00,446 - INFO - machamp.model.trainer - cmd: train.py --dataset_configs configs/nlu_en.json --device 0
# 2024-05-24 20:40:00,542 - INFO - machamp.model.trainer - GPU: Tesla V100-SXM2-32GB
# 2024-05-24 20:40:00,542 - INFO - machamp.model.trainer - Torch version: 2.3.0+cu121
# 2024-05-24 20:40:00,542 - INFO - machamp.model.trainer - Transformers version: 4.41.1
# 2024-05-24 20:40:00,543 - INFO - machamp.model.trainer - MaChAmp git version 9f5a6ce48fcebed353956f28de59d9d99098f073
# 2024-05-24 20:40:04,483 - INFO - machamp.data.machamp_dataset - Reading /home/afkhabirzyanova_3/jupyterhub_slurm/machamp/data/xSID-0.3/en.train.conll...
# 2024-05-24 20:41:44,825 - INFO - machamp.readers.read_sequence - Stats NLU (/home/afkhabirzyanova_3/jupyterhub_slurm/machamp/data/xSID-0.3/en.train.conll):
# 2024-05-24 20:41:44,830 - INFO - machamp.readers.read_sequence - Lines:      43,605
# 2024-05-24 20:41:44,831 - INFO - machamp.readers.read_sequence - Words:      341,184
# 2024-05-24 20:41:44,831 - INFO - machamp.readers.read_sequence - Subwords:   449,359
# 2024-05-24 20:41:44,831 - INFO - machamp.readers.read_sequence - Unks:       0
# 2024-05-24 20:41:44,831 - INFO - machamp.readers.read_sequence - Pre-splits: 0
# 2024-05-24 20:41:44,953 - INFO - machamp.data.machamp_dataset - Done reading /home/afkhabirzyanova_3/jupyterhub_slurm/machamp/data/xSID-0.3/en.train.conll (100.0s)
#
# 2024-05-24 20:41:44,964 - ERROR - STDERR - /home/afkhabirzyanova_3/.local/lib/python3.10/site-packages/torch/utils/data/sampler.py:64: UserWarning: `data_source` argument is not used and will be removed in 2.2.0.You may still have custom implementation that utilizes it.
# 2024-05-24 20:41:44,965 - ERROR - STDERR -   warnings.warn("`data_source` argument is not used and will be removed in 2.2.0."
# 2024-05-24 20:41:49,092 - INFO - machamp.data.machamp_dataset - Reading /home/afkhabirzyanova_3/jupyterhub_slurm/machamp/data/xSID-tat/final_tat.valid.conll...
# 2024-05-24 20:41:49,319 - INFO - machamp.readers.read_sequence - Stats NLU (/home/afkhabirzyanova_3/jupyterhub_slurm/machamp/data/xSID-tat/final_tat.valid.conll):
# 2024-05-24 20:41:49,334 - INFO - machamp.readers.read_sequence - Lines:      100
# 2024-05-24 20:41:49,335 - INFO - machamp.readers.read_sequence - Words:      622
# 2024-05-24 20:41:49,335 - INFO - machamp.readers.read_sequence - Subwords:   1,438
# 2024-05-24 20:41:49,335 - INFO - machamp.readers.read_sequence - Unks:       0
# 2024-05-24 20:41:49,335 - INFO - machamp.readers.read_sequence - Pre-splits: 0
# 2024-05-24 20:41:49,335 - INFO - machamp.data.machamp_dataset - Done reading /home/afkhabirzyanova_3/jupyterhub_slurm/machamp/data/xSID-tat/final_tat.valid.conll (0.0s)
#
# 2024-05-24 20:41:55,083 - INFO - machamp.model.machamp - Overview of the torch model:
# 2024-05-24 20:41:55,099 - INFO - machamp.model.machamp - MachampModel(
#   (mlm): DebertaV2Model(
#     (embeddings): DebertaV2Embeddings(
#       (word_embeddings): Embedding(251000, 768, padding_idx=0)
#       (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#       (dropout): StableDropout()
#     )
#     (encoder): DebertaV2Encoder(
#       (layer): ModuleList(
#         (0-11): 12 x DebertaV2Layer(
#           (attention): DebertaV2Attention(
#             (self): DisentangledSelfAttention(
#               (query_proj): Linear(in_features=768, out_features=768, bias=True)
#               (key_proj): Linear(in_features=768, out_features=768, bias=True)
#               (value_proj): Linear(in_features=768, out_features=768, bias=True)
#               (pos_dropout): StableDropout()
#               (dropout): StableDropout()
#             )
#             (output): DebertaV2SelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#               (dropout): StableDropout()
#             )
#           )
#           (intermediate): DebertaV2Intermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaV2Output(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#             (dropout): StableDropout()
#           )
#         )
#       )
#       (rel_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#     )
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
#   (decoders): ModuleDict(
#     (intent): MachampClassificationDecoder(
#       (hidden_to_label): Linear(in_features=768, out_features=19, bias=True)
#       (loss_function): CrossEntropyLoss()
#       (decoder_dropout): Dropout(p=0.0, inplace=False)
#     )
#     (slots): MachampSeqDecoder(
#       (hidden_to_label): Linear(in_features=768, out_features=73, bias=True)
#       (loss_function): CrossEntropyLoss()
#       (decoder_dropout): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (scalars): ModuleDict(
#     (intent): None
#     (slots): None
#   )
#   (dataset_embedder): Embedding(1, 768)
# )
# 2024-05-24 20:41:55,219 - INFO - machamp.utils.myutils - Done constructing parameter groups.
# 2024-05-24 20:41:55,232 - INFO - machamp.utils.myutils - Group 0: ['mlm.encoder.LayerNorm.bias', 'mlm.encoder.layer.2.attention.output.LayerNorm.weight', 'mlm.encoder.layer.0.attention.self.key_proj.weight', 'mlm.encoder.layer.4.attention.self.value_proj.bias', 'mlm.encoder.layer.3.attention.output.dense.bias', 'mlm.encoder.layer.1.output.LayerNorm.bias', 'mlm.encoder.layer.3.attention.self.key_proj.weight', 'mlm.encoder.layer.11.output.LayerNorm.weight', 'mlm.encoder.layer.5.output.dense.bias', 'mlm.encoder.layer.4.attention.output.LayerNorm.bias', 'mlm.encoder.layer.10.output.LayerNorm.bias', 'mlm.encoder.layer.0.intermediate.dense.bias', 'mlm.encoder.layer.6.attention.self.query_proj.weight', 'mlm.encoder.layer.10.attention.self.value_proj.bias', 'mlm.encoder.layer.10.attention.output.dense.weight', 'mlm.encoder.layer.11.attention.output.dense.weight', 'mlm.encoder.layer.11.attention.output.dense.bias', 'mlm.encoder.layer.1.attention.output.LayerNorm.weight', 'mlm.encoder.layer.7.attention.output.LayerNorm.bias', 'mlm.encoder.layer.3.output.LayerNorm.weight', 'mlm.encoder.layer.6.attention.self.value_proj.weight', 'mlm.encoder.layer.6.output.dense.bias', 'mlm.encoder.layer.5.output.dense.weight', 'mlm.encoder.layer.10.attention.self.value_proj.weight', 'mlm.encoder.layer.4.intermediate.dense.weight', 'mlm.encoder.layer.1.output.dense.weight', 'mlm.encoder.layer.7.attention.output.dense.weight', 'mlm.encoder.layer.10.attention.self.key_proj.weight', 'mlm.encoder.layer.10.output.dense.weight', 'mlm.encoder.layer.2.attention.self.value_proj.bias', 'mlm.encoder.layer.0.attention.output.dense.weight', 'mlm.encoder.layer.3.attention.output.LayerNorm.bias', 'mlm.encoder.layer.3.output.dense.weight', 'mlm.encoder.layer.4.attention.output.LayerNorm.weight', 'mlm.encoder.layer.0.output.LayerNorm.weight', 'mlm.encoder.layer.4.intermediate.dense.bias', 'mlm.encoder.layer.10.attention.output.LayerNorm.weight', 'mlm.encoder.layer.9.attention.self.value_proj.weight', 'mlm.encoder.layer.10.attention.output.LayerNorm.bias', 'mlm.encoder.layer.5.attention.self.value_proj.bias', 'mlm.encoder.layer.11.attention.output.LayerNorm.weight', 'mlm.encoder.layer.4.output.LayerNorm.weight', 'mlm.encoder.layer.8.attention.self.key_proj.weight', 'mlm.encoder.layer.1.attention.output.dense.weight', 'mlm.encoder.layer.8.attention.output.dense.weight', 'mlm.embeddings.LayerNorm.bias', 'mlm.encoder.layer.9.attention.self.key_proj.bias', 'mlm.encoder.layer.2.intermediate.dense.weight', 'mlm.encoder.layer.1.output.dense.bias', 'mlm.encoder.layer.5.attention.self.key_proj.bias', 'mlm.encoder.layer.5.intermediate.dense.weight', 'mlm.encoder.layer.0.output.dense.weight', 'mlm.encoder.layer.4.output.dense.weight', 'mlm.encoder.layer.0.attention.self.query_proj.bias', 'mlm.encoder.layer.5.output.LayerNorm.weight', 'mlm.encoder.layer.0.output.dense.bias', 'mlm.encoder.layer.6.output.LayerNorm.weight', 'mlm.encoder.layer.7.output.LayerNorm.bias', 'mlm.encoder.layer.0.attention.output.LayerNorm.bias', 'mlm.encoder.layer.4.output.LayerNorm.bias', 'mlm.encoder.layer.2.attention.self.query_proj.bias', 'mlm.encoder.layer.7.attention.self.value_proj.weight', 'mlm.encoder.layer.3.output.dense.bias', 'mlm.encoder.layer.3.intermediate.dense.bias', 'mlm.encoder.layer.9.attention.self.key_proj.weight', 'mlm.encoder.layer.0.attention.self.value_proj.weight', 'mlm.encoder.layer.10.attention.self.key_proj.bias', 'mlm.encoder.layer.11.attention.self.value_proj.weight', 'mlm.encoder.layer.3.attention.self.key_proj.bias', 'mlm.encoder.layer.10.output.dense.bias', 'mlm.encoder.layer.7.output.LayerNorm.weight', 'mlm.encoder.layer.3.attention.self.query_proj.bias', 'mlm.encoder.layer.7.intermediate.dense.weight', 'mlm.encoder.layer.0.attention.output.LayerNorm.weight', 'mlm.encoder.layer.4.output.dense.bias', 'mlm.encoder.layer.6.attention.output.LayerNorm.bias', 'mlm.encoder.layer.6.attention.self.query_proj.bias', 'mlm.encoder.LayerNorm.weight', 'mlm.encoder.layer.11.attention.self.k ...
# 2024-05-24 20:41:55,233 - INFO - machamp.utils.myutils - Group 1: ['decoders.slots.hidden_to_label.bias', 'decoders.intent.hidden_to_label.bias', 'decoders.intent.hidden_to_label.weight', 'dataset_embedder.weight', 'decoders.slots.hidden_to_label.weight'], {}
# 2024-05-24 20:41:55,233 - INFO - machamp.utils.myutils - Group 2: [], {}
# 2024-05-24 20:41:55,233 - WARNING - machamp.utils.myutils - When constructing parameter groups, scalars.* does not match any parameter name
# 2024-05-24 20:41:55,234 - INFO - machamp.utils.myutils - Number of trainable parameters: 278290268
# 2024-05-24 20:41:55,256 - ERROR - STDERR - /home/afkhabirzyanova_3/.local/lib/python3.10/site-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# 2024-05-24 20:41:55,256 - ERROR - STDERR -   warnings.warn(
# 2024-05-24 20:41:57,210 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing. Training only the decoder heads, not the MLM.
# 2024-05-24 20:41:57,226 - INFO - machamp.model.trainer - MaChAmp succesfully initialized in 117.0s
# 2024-05-24 20:41:57,227 - INFO - machamp.model.trainer -
#
#           CHAMP!                   %%#/
#  ###/%(        CHAMP!            ,#//(%%#(
# #%%/((/(            . , ,       .%%#####%(
# #(/(((###(        ////////%     *//((((((/
#   ,((((//        #%(%#/#%%/          &####
#      ###### *#%%@&((//&@#%&(%%#%%%%#%%####
#      ,####(%%###%#&&&#((&&(((%%%%########(
#        ///((%%%##/%%######((%%%%%%%%((((//
#           %%%%%##((/%(///%%##%%%%%%%##
#         /%%####%%%%%%#%%#/(%#(((%%%%%&.
#        &#%/#%%###%%%##%%%((###(//(####(
#      @&%%#////(########%######((/(////(
#        #////     ((((##(((((////,
#                    */(//(((/**,.
#                   #,**%#%,*,,,*(
#                /%%%%%/,,,,,(%%%%((
#               &%%%#(((/*  /(#%%%#(/
#               %%#(((//     ,((###(/
#              .%(/(/,         /(###/(
#               %(((//          (/((///
#                ((/,             /(//
#              %%%#((,            &%%%#
#          /#(#%(/,             /###*##*
#
# 2024-05-24 20:41:57,227 - INFO - machamp.model.trainer - starting training...
# 2024-05-24 20:41:57,227 - INFO - machamp.model.trainer - Epoch 1/20: training
# 100%|███████████████████████████████████████| 1363/1363 [02:39<00:00,  8.57it/s]
# 2024-05-24 20:44:36,326 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-05-24 20:44:36,327 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 3.125e-06
# 2024-05-24 20:44:36,327 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 3.125e-06
# 2024-05-24 20:44:36,327 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 1.1875e-06
# 2024-05-24 20:44:36,327 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-05-24 20:44:36,327 - INFO - machamp.model.trainer - Epoch 1: evaluating on dev
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00,  7.95it/s]
# 2024-05-24 20:44:36,833 - INFO - machamp.model.callback - epoch       : 1/20
# 2024-05-24 20:44:36,834 - INFO - machamp.model.callback - best_epoch  : 1
# 2024-05-24 20:44:36,834 - INFO - machamp.model.callback - max_gpu_mem : 3.4382
# 2024-05-24 20:44:36,834 - INFO - machamp.model.callback - cur_ram     : 1.5826
# 2024-05-24 20:44:36,834 - INFO - machamp.model.callback - time_epoch  : 0:02:39
# 2024-05-24 20:44:36,834 - INFO - machamp.model.callback - time_total  : 0:02:39
# 2024-05-24 20:44:36,834 - INFO - machamp.model.callback -
# 2024-05-24 20:44:36,834 - INFO - machamp.model.callback -                 train_loss dev_loss train_scores dev_scores
# 2024-05-24 20:44:36,834 - INFO - machamp.model.callback - Best (1)
# 2024-05-24 20:44:36,835 - INFO - machamp.model.callback - intent_accuracy    75.2104  60.3753       0.3208     0.2900
# 2024-05-24 20:44:36,835 - INFO - machamp.model.callback - slots_accuracy      1.9735   2.4949       0.5246     0.4486
# 2024-05-24 20:44:36,835 - INFO - machamp.model.callback - sum                77.1839  62.8701       0.8454     0.7386
# 2024-05-24 20:44:36,835 - INFO - machamp.model.callback - Epoch 1
# 2024-05-24 20:44:36,835 - INFO - machamp.model.callback - intent_accuracy    75.2104  60.3753       0.3208     0.2900
# 2024-05-24 20:44:36,835 - INFO - machamp.model.callback - slots_accuracy      1.9735   2.4949       0.5246     0.4486
# 2024-05-24 20:44:36,835 - INFO - machamp.model.callback - sum                77.1839  62.8701       0.8454     0.7386
# 2024-05-24 20:44:36,920 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# ││                             ▘                             │
# ││                                                           │
# ││                                                           │
# ││                                                           │
# ││                                                           │
# ││                                                           │ 0.40
# ││                                                           │
# ││                                                           │
# ││                                                           │
# ││                                                           │
# ││                                                           │ 0.35
# ││                                                           │
# ││                                                           │
# ││                                                           │
# ││                                                           │
# ││                                                           │ 0.30
# ││                             ▖                             │
# └────────────────────────────────────────────────────────────┘
# 0.0            0.5            1.0            1.5
#                           ██ intent
#                           ██ slots
# 2024-05-24 20:44:36,930 - INFO - machamp.model.callback - Performance of 0.7386 within top 1 models, saving to logs/nlu_en/2024.05.24_20.40.00/model_1.pt
# 2024-05-24 20:44:41,885 - INFO - machamp.model.trainer - Saving training state, so that we can use --resume if needed
# 2024-05-24 20:44:41,886 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_1.pt
# 2024-05-24 20:44:41,901 - INFO - machamp.model.trainer - Epoch 2/20: training
# 100%|███████████████████████████████████████| 1363/1363 [05:48<00:00,  3.91it/s]
# 2024-05-24 20:50:30,811 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-05-24 20:50:30,811 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 2.012083279701377e-05
# 2024-05-24 20:50:30,811 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 2.012083279701377e-05
# 2024-05-24 20:50:30,811 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 7.645916462865233e-06
# 2024-05-24 20:50:30,812 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-05-24 20:50:30,812 - INFO - machamp.model.trainer - Epoch 2: evaluating on dev
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00,  9.20it/s]
# 2024-05-24 20:50:31,250 - INFO - machamp.model.callback - epoch       : 2/20
# 2024-05-24 20:50:31,250 - INFO - machamp.model.callback - best_epoch  : 2
# 2024-05-24 20:50:31,250 - INFO - machamp.model.callback - max_gpu_mem : 6.7802
# 2024-05-24 20:50:31,250 - INFO - machamp.model.callback - cur_ram     : 1.6567
# 2024-05-24 20:50:31,251 - INFO - machamp.model.callback - time_epoch  : 0:05:49
# 2024-05-24 20:50:31,251 - INFO - machamp.model.callback - time_total  : 0:08:34
# 2024-05-24 20:50:31,251 - INFO - machamp.model.callback -
# 2024-05-24 20:50:31,251 - INFO - machamp.model.callback -                 train_loss dev_loss train_scores dev_scores
# 2024-05-24 20:50:31,251 - INFO - machamp.model.callback - Best (2)
# 2024-05-24 20:50:31,251 - INFO - machamp.model.callback - intent_accuracy    27.3752  16.1406       0.7717     0.8300
# 2024-05-24 20:50:31,251 - INFO - machamp.model.callback - slots_accuracy      1.2139   2.1463       0.6739     0.5032
# 2024-05-24 20:50:31,251 - INFO - machamp.model.callback - sum                28.5891  18.2869       1.4456     1.3332
# 2024-05-24 20:50:31,252 - INFO - machamp.model.callback - Epoch 2
# 2024-05-24 20:50:31,252 - INFO - machamp.model.callback - intent_accuracy    27.3752  16.1406       0.7717     0.8300
# 2024-05-24 20:50:31,252 - INFO - machamp.model.callback - slots_accuracy      1.2139   2.1463       0.6739     0.5032
# 2024-05-24 20:50:31,252 - INFO - machamp.model.callback - sum                28.5891  18.2869       1.4456     1.3332
# 2024-05-24 20:50:31,305 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │                                                        ▗▄▀▀│ 0.8
# │                                                     ▄▞▀▘   │
# │                                                 ▗▄▀▀       │
# │                                              ▄▞▀▘          │
# │                                          ▗▄▀▀              │
# │                                       ▄▞▀▘                 │
# │                                   ▗▄▀▀                     │
# │                                ▄▞▀▘                        │ 0.6
# │                            ▄▄▀▀                            │
# │                        ▗▄▞▀                                │
# │                     ▄▄▀▘          ▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▞▀▀▀▀▀▀▀│
# │▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▞▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀                         │
# │▘             ▄▄▀▘                                          │
# │          ▗▄▞▀                                              │ 0.4
# │       ▄▄▀▘                                                 │
# │   ▗▄▞▀                                                     │
# │▄▄▀▘                                                        │
# └────────────────────────────────────────────────────────────┘
# 1.0                           1.5                          2.0
#                           ██ intent
#                           ██ slots
# 2024-05-24 20:50:31,317 - INFO - machamp.model.callback - Performance of 1.3332 within top 1 models, saving to logs/nlu_en/2024.05.24_20.40.00/model_2.pt
# 2024-05-24 20:50:36,099 - INFO - machamp.model.callback - Removing old model: logs/nlu_en/2024.05.24_20.40.00/model_1.pt
# 2024-05-24 20:50:36,850 - INFO - machamp.model.trainer - Saving training state, so that we can use --resume if needed
# 2024-05-24 20:50:36,850 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_2.pt
# 2024-05-24 20:50:46,271 - INFO - machamp.model.trainer - Removing old training state.
# 2024-05-24 20:50:46,271 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_1.pt
# 2024-05-24 20:50:46,279 - INFO - machamp.model.trainer - Epoch 3/20: training
# 100%|███████████████████████████████████████| 1363/1363 [05:47<00:00,  3.93it/s]
# 2024-05-24 20:56:33,482 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-05-24 20:56:33,483 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 3.711666559402755e-05
# 2024-05-24 20:56:33,483 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 3.711666559402755e-05
# 2024-05-24 20:56:33,484 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 1.4104332925730467e-05
# 2024-05-24 20:56:33,484 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-05-24 20:56:33,485 - INFO - machamp.model.trainer - Epoch 3: evaluating on dev
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00,  9.34it/s]
# 2024-05-24 20:56:33,917 - INFO - machamp.model.callback - epoch       : 3/20
# 2024-05-24 20:56:33,918 - INFO - machamp.model.callback - best_epoch  : 3
# 2024-05-24 20:56:33,918 - INFO - machamp.model.callback - max_gpu_mem : 6.7849
# 2024-05-24 20:56:33,918 - INFO - machamp.model.callback - cur_ram     : 1.6571
# 2024-05-24 20:56:33,918 - INFO - machamp.model.callback - time_epoch  : 0:05:47
# 2024-05-24 20:56:33,918 - INFO - machamp.model.callback - time_total  : 0:14:36
# 2024-05-24 20:56:33,918 - INFO - machamp.model.callback -
# 2024-05-24 20:56:33,919 - INFO - machamp.model.callback -                 train_loss dev_loss train_scores dev_scores
# 2024-05-24 20:56:33,919 - INFO - machamp.model.callback - Best (3)
# 2024-05-24 20:56:33,919 - INFO - machamp.model.callback - intent_accuracy     2.6558  14.0150       0.9816     0.7900
# 2024-05-24 20:56:33,920 - INFO - machamp.model.callback - slots_accuracy      0.7629   1.6437       0.7803     0.6077
# 2024-05-24 20:56:33,920 - INFO - machamp.model.callback - sum                 3.4187  15.6587       1.7619     1.3977
# 2024-05-24 20:56:33,920 - INFO - machamp.model.callback - Epoch 3
# 2024-05-24 20:56:33,920 - INFO - machamp.model.callback - intent_accuracy     2.6558  14.0150       0.9816     0.7900
# 2024-05-24 20:56:33,921 - INFO - machamp.model.callback - slots_accuracy      0.7629   1.6437       0.7803     0.6077
# 2024-05-24 20:56:33,921 - INFO - machamp.model.callback - sum                 3.4187  15.6587       1.7619     1.3977
# 2024-05-24 20:56:33,984 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │                            ▗▀▀▀▀▀▀▀▀▀▀▀▀▚▄▄▄▄▄▄▄▄▄▄▄▖      │ 0.8
# │                          ▗▞▘                        ▝▀▀▀▀▀▀│
# │                        ▗▞▘                                 │
# │                       ▄▘                                   │
# │                     ▄▀                                     │
# │                   ▗▞                                       │
# │                 ▗▞▘                                        │
# │                ▄▘                                 ▄▄▄▄▞▀▀▀▀│ 0.6
# │              ▄▀                         ▗▄▄▄▄▞▀▀▀▀         │
# │            ▗▞                  ▗▄▄▄▄▀▀▀▀▘                  │
# │          ▗▞▘    ▗▄▄▄▄▄▄▄▄▀▀▀▀▀▀▘                           │
# │▄▄▄▄▄▄▄▄▄▀▀▀▀▀▀▀▀▘                                          │
# │▘      ▄▀                                                   │
# │     ▗▀                                                     │ 0.4
# │   ▗▞▘                                                      │
# │  ▞▘                                                        │
# │▄▀                                                          │
# └────────────────────────────────────────────────────────────┘
#  1                             2                            3
#                           ██ intent
#                           ██ slots
# 2024-05-24 20:56:34,002 - INFO - machamp.model.callback - Performance of 1.3977 within top 1 models, saving to logs/nlu_en/2024.05.24_20.40.00/model_3.pt
# 2024-05-24 20:56:38,906 - INFO - machamp.model.callback - Removing old model: logs/nlu_en/2024.05.24_20.40.00/model_2.pt
# 2024-05-24 20:56:39,707 - INFO - machamp.model.trainer - Saving training state, so that we can use --resume if needed
# 2024-05-24 20:56:39,707 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_3.pt
# 2024-05-24 20:56:49,169 - INFO - machamp.model.trainer - Removing old training state.
# 2024-05-24 20:56:49,170 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_2.pt
# 2024-05-24 20:56:50,689 - INFO - machamp.model.trainer - Epoch 4/20: training
# 100%|███████████████████████████████████████| 1363/1363 [05:49<00:00,  3.90it/s]
# 2024-05-24 21:02:40,221 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-05-24 21:02:40,222 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 5.411249839104132e-05
# 2024-05-24 21:02:40,222 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 5.411249839104132e-05
# 2024-05-24 21:02:40,223 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 2.0562749388595704e-05
# 2024-05-24 21:02:40,223 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-05-24 21:02:40,226 - INFO - machamp.model.trainer - Epoch 4: evaluating on dev
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00,  9.85it/s]
# 2024-05-24 21:02:40,657 - INFO - machamp.model.callback - epoch       : 4/20
# 2024-05-24 21:02:40,658 - INFO - machamp.model.callback - best_epoch  : 4
# 2024-05-24 21:02:40,658 - INFO - machamp.model.callback - max_gpu_mem : 6.7849
# 2024-05-24 21:02:40,658 - INFO - machamp.model.callback - cur_ram     : 1.6568
# 2024-05-24 21:02:40,658 - INFO - machamp.model.callback - time_epoch  : 0:05:49
# 2024-05-24 21:02:40,658 - INFO - machamp.model.callback - time_total  : 0:20:43
# 2024-05-24 21:02:40,658 - INFO - machamp.model.callback -
# 2024-05-24 21:02:40,658 - INFO - machamp.model.callback -                 train_loss dev_loss train_scores dev_scores
# 2024-05-24 21:02:40,659 - INFO - machamp.model.callback - Best (4)
# 2024-05-24 21:02:40,659 - INFO - machamp.model.callback - intent_accuracy     1.5527  14.5033       0.9874     0.8400
# 2024-05-24 21:02:40,659 - INFO - machamp.model.callback - slots_accuracy      0.4400   1.4263       0.8669     0.6543
# 2024-05-24 21:02:40,659 - INFO - machamp.model.callback - sum                 1.9927  15.9296       1.8543     1.4943
# 2024-05-24 21:02:40,660 - INFO - machamp.model.callback - Epoch 4
# 2024-05-24 21:02:40,660 - INFO - machamp.model.callback - intent_accuracy     1.5527  14.5033       0.9874     0.8400
# 2024-05-24 21:02:40,660 - INFO - machamp.model.callback - slots_accuracy      0.4400   1.4263       0.8669     0.6543
# 2024-05-24 21:02:40,660 - INFO - machamp.model.callback - sum                 1.9927  15.9296       1.8543     1.4943
# 2024-05-24 21:02:40,727 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │                   ▄▀▀▀▄▄▄▄▄▄▄▄                ▄▄▄▄▄▄▞▀▀▀▀▀▀│
# │                  ▞            ▀▀▀▀▀▀▀▀▄▞▀▀▀▀▀▀             │ 0.8
# │                 ▞                                          │
# │               ▗▀                                           │
# │              ▗▘                                            │
# │             ▄▘                                         ▗▄▄▄│
# │            ▞                             ▗▄▄▄▄▄▄▞▀▀▀▀▀▀▘   │
# │           ▞                       ▄▄▄▀▀▀▀▘                 │ 0.6
# │         ▗▀                 ▗▄▄▄▀▀▀                         │
# │        ▗▘            ▗▄▄▞▀▀▘                               │
# │       ▄▘    ▄▄▄▄▄▄▀▀▀▘                                     │
# │ ▄▄▄▄▄▄▀▀▀▀▀▀                                               │
# │▀    ▞                                                      │
# │   ▗▀                                                       │ 0.4
# │  ▗▘                                                        │
# │ ▄▘                                                         │
# │▞                                                           │
# └────────────────────────────────────────────────────────────┘
#  1                   2                  3                   4
#                           ██ intent
#                           ██ slots
# 2024-05-24 21:02:40,728 - INFO - machamp.model.callback - Performance of 1.4943 within top 1 models, saving to logs/nlu_en/2024.05.24_20.40.00/model_4.pt
# 2024-05-24 21:02:45,533 - INFO - machamp.model.callback - Removing old model: logs/nlu_en/2024.05.24_20.40.00/model_3.pt
# 2024-05-24 21:02:46,301 - INFO - machamp.model.trainer - Saving training state, so that we can use --resume if needed
# 2024-05-24 21:02:46,306 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_4.pt
# 2024-05-24 21:02:56,224 - INFO - machamp.model.trainer - Removing old training state.
# 2024-05-24 21:02:56,224 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_3.pt
# 2024-05-24 21:02:57,687 - INFO - machamp.model.trainer - Epoch 5/20: training
# 100%|███████████████████████████████████████| 1363/1363 [05:50<00:00,  3.89it/s]
# 2024-05-24 21:08:48,136 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-05-24 21:08:48,137 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 7.110833118805509e-05
# 2024-05-24 21:08:48,137 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 7.110833118805509e-05
# 2024-05-24 21:08:48,137 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 2.7021165851460933e-05
# 2024-05-24 21:08:48,138 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-05-24 21:08:48,138 - INFO - machamp.model.trainer - Epoch 5: evaluating on dev
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00,  9.54it/s]
# 2024-05-24 21:08:48,563 - INFO - machamp.model.callback - epoch       : 5/20
# 2024-05-24 21:08:48,563 - INFO - machamp.model.callback - best_epoch  : 4
# 2024-05-24 21:08:48,563 - INFO - machamp.model.callback - max_gpu_mem : 6.7849
# 2024-05-24 21:08:48,563 - INFO - machamp.model.callback - cur_ram     : 1.6556
# 2024-05-24 21:08:48,564 - INFO - machamp.model.callback - time_epoch  : 0:05:50
# 2024-05-24 21:08:48,564 - INFO - machamp.model.callback - time_total  : 0:26:51
# 2024-05-24 21:08:48,564 - INFO - machamp.model.callback -
# 2024-05-24 21:08:48,564 - INFO - machamp.model.callback -                 train_loss dev_loss train_scores dev_scores
# 2024-05-24 21:08:48,565 - INFO - machamp.model.callback - Best (4)
# 2024-05-24 21:08:48,565 - INFO - machamp.model.callback - intent_accuracy     1.5527  14.5033       0.9874     0.8400
# 2024-05-24 21:08:48,566 - INFO - machamp.model.callback - slots_accuracy      0.4400   1.4263       0.8669     0.6543
# 2024-05-24 21:08:48,566 - INFO - machamp.model.callback - sum                 1.9927  15.9296       1.8543     1.4943
# 2024-05-24 21:08:48,566 - INFO - machamp.model.callback - Epoch 5
# 2024-05-24 21:08:48,566 - INFO - machamp.model.callback - intent_accuracy     1.2755  19.9568       0.9898     0.7900
# 2024-05-24 21:08:48,567 - INFO - machamp.model.callback - slots_accuracy      0.2916   1.2263       0.9081     0.6704
# 2024-05-24 21:08:48,567 - INFO - machamp.model.callback - sum                 1.5671  21.1831       1.8979     1.4604
# 2024-05-24 21:08:48,634 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │              ▗▄▄▄▖                    ▄▄▄▀▀▀▀▀▀▄▄▖         │
# │              ▞   ▝▀▀▀▄▄▄▄       ▗▄▄▀▀▀           ▝▀▀▚▄▄▖   │
# │             ▗▘           ▀▀▀▚▞▀▀▘                      ▝▀▀▚│ 0.8
# │             ▞                                              │
# │            ▐                                               │
# │            ▌                                               │
# │           ▐                                                │
# │           ▌                                                │ 0.7
# │          ▐                                         ▄▄▄▄▄▄▄▄│
# │         ▗▘                              ▄▄▄▀▀▀▀▀▀▀▀        │
# │         ▞                        ▗▄▄▄▀▀▀                   │
# │        ▗▘                   ▄▄▞▀▀▘                         │
# │        ▞                 ▗▄▀                               │ 0.6
# │       ▗▘              ▗▄▀▘                                 │
# │       ▌            ▗▄▀▘                                    │
# │      ▐           ▄▞▘                                       │
# │      ▌     ▗▄▄▄▞▀                                          │
# └────────────────────────────────────────────────────────────┘
#  1              2              3             4              5
#                           ██ intent
#                           ██ slots
# 2024-05-24 21:08:48,635 - INFO - machamp.model.trainer - Saving training state, so that we can use --resume if needed
# 2024-05-24 21:08:48,635 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_5.pt
# 2024-05-24 21:08:58,484 - INFO - machamp.model.trainer - Removing old training state.
# 2024-05-24 21:08:58,484 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_4.pt
# 2024-05-24 21:08:59,446 - INFO - machamp.model.trainer - Epoch 6/20: training
# 100%|███████████████████████████████████████| 1363/1363 [05:51<00:00,  3.88it/s]
# 2024-05-24 21:14:51,152 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-05-24 21:14:51,154 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 8.810416398506886e-05
# 2024-05-24 21:14:51,154 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 8.810416398506886e-05
# 2024-05-24 21:14:51,154 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 3.347958231432617e-05
# 2024-05-24 21:14:51,154 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-05-24 21:14:51,155 - INFO - machamp.model.trainer - Epoch 6: evaluating on dev
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00,  9.53it/s]
# 2024-05-24 21:14:51,580 - INFO - machamp.model.callback - epoch       : 6/20
# 2024-05-24 21:14:51,582 - INFO - machamp.model.callback - best_epoch  : 4
# 2024-05-24 21:14:51,583 - INFO - machamp.model.callback - max_gpu_mem : 6.7849
# 2024-05-24 21:14:51,583 - INFO - machamp.model.callback - cur_ram     : 1.6558
# 2024-05-24 21:14:51,583 - INFO - machamp.model.callback - time_epoch  : 0:05:52
# 2024-05-24 21:14:51,583 - INFO - machamp.model.callback - time_total  : 0:32:54
# 2024-05-24 21:14:51,583 - INFO - machamp.model.callback -
# 2024-05-24 21:14:51,584 - INFO - machamp.model.callback -                 train_loss dev_loss train_scores dev_scores
# 2024-05-24 21:14:51,584 - INFO - machamp.model.callback - Best (4)
# 2024-05-24 21:14:51,584 - INFO - machamp.model.callback - intent_accuracy     1.5527  14.5033       0.9874     0.8400
# 2024-05-24 21:14:51,584 - INFO - machamp.model.callback - slots_accuracy      0.4400   1.4263       0.8669     0.6543
# 2024-05-24 21:14:51,585 - INFO - machamp.model.callback - sum                 1.9927  15.9296       1.8543     1.4943
# 2024-05-24 21:14:51,585 - INFO - machamp.model.callback - Epoch 6
# 2024-05-24 21:14:51,585 - INFO - machamp.model.callback - intent_accuracy     1.2558  24.9268       0.9901     0.7900
# 2024-05-24 21:14:51,585 - INFO - machamp.model.callback - slots_accuracy      0.2256   1.1267       0.9284     0.6994
# 2024-05-24 21:14:51,586 - INFO - machamp.model.callback - sum                 1.4814  26.0535       1.9185     1.4894
# 2024-05-24 21:14:51,659 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │           ▗▄▄▄                ▗▄▞▀▀▀▀▄▄▖                   │
# │           ▞   ▀▀▀▄▄▄     ▗▄▄▀▀▘        ▝▀▀▄▄▖              │
# │           ▌         ▀▀▚▛▀▘                  ▝▀▚▄▄▄▄▄▄▄▄▄▄▄▄│ 0.8
# │          ▐                                                 │
# │          ▌                                                 │
# │         ▐                                                  │
# │         ▞                                                  │
# │        ▗▘                                          ▗▄▄▄▄▀▀▀│ 0.7
# │        ▞                                ▗▄▄▄▄▄▄▞▀▀▀▘       │
# │       ▗▘                        ▄▄▞▀▀▀▀▀▘                  │
# │       ▐                    ▄▄▞▀▀                           │
# │       ▌               ▗▄▀▀▀                                │
# │      ▐              ▄▞▘                                    │ 0.6
# │      ▌            ▄▀                                       │
# │     ▐          ▗▞▀                                         │
# │     ▞        ▗▞▘                                           │
# │    ▗▘    ▄▄▄▀▘                                             │
# └────────────────────────────────────────────────────────────┘
#  1           2           3          4           5           6
#                           ██ intent
#                           ██ slots
# 2024-05-24 21:14:51,660 - INFO - machamp.model.trainer - Saving training state, so that we can use --resume if needed
# 2024-05-24 21:14:51,660 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_6.pt
# 2024-05-24 21:15:01,676 - INFO - machamp.model.trainer - Removing old training state.
# 2024-05-24 21:15:01,676 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_5.pt
# 2024-05-24 21:15:02,608 - INFO - machamp.model.trainer - Epoch 7/20: training
# 100%|███████████████████████████████████████| 1363/1363 [05:49<00:00,  3.90it/s]
# 2024-05-24 21:20:52,192 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-05-24 21:20:52,192 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 9.781432728375994e-05
# 2024-05-24 21:20:52,193 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 9.781432728375994e-05
# 2024-05-24 21:20:52,193 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 3.716944436782878e-05
# 2024-05-24 21:20:52,193 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-05-24 21:20:52,193 - INFO - machamp.model.trainer - Epoch 7: evaluating on dev
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 10.53it/s]
# 2024-05-24 21:20:52,576 - INFO - machamp.model.callback - epoch       : 7/20
# 2024-05-24 21:20:52,576 - INFO - machamp.model.callback - best_epoch  : 4
# 2024-05-24 21:20:52,576 - INFO - machamp.model.callback - max_gpu_mem : 6.7849
# 2024-05-24 21:20:52,576 - INFO - machamp.model.callback - cur_ram     : 1.6558
# 2024-05-24 21:20:52,576 - INFO - machamp.model.callback - time_epoch  : 0:05:49
# 2024-05-24 21:20:52,577 - INFO - machamp.model.callback - time_total  : 0:38:55
# 2024-05-24 21:20:52,577 - INFO - machamp.model.callback -
# 2024-05-24 21:20:52,578 - INFO - machamp.model.callback -                 train_loss dev_loss train_scores dev_scores
# 2024-05-24 21:20:52,583 - INFO - machamp.model.callback - Best (4)
# 2024-05-24 21:20:52,583 - INFO - machamp.model.callback - intent_accuracy     1.5527  14.5033       0.9874     0.8400
# 2024-05-24 21:20:52,584 - INFO - machamp.model.callback - slots_accuracy      0.4400   1.4263       0.8669     0.6543
# 2024-05-24 21:20:52,584 - INFO - machamp.model.callback - sum                 1.9927  15.9296       1.8543     1.4943
# 2024-05-24 21:20:52,584 - INFO - machamp.model.callback - Epoch 7
# 2024-05-24 21:20:52,584 - INFO - machamp.model.callback - intent_accuracy     1.1627  31.2667       0.9894     0.7600
# 2024-05-24 21:20:52,584 - INFO - machamp.model.callback - slots_accuracy      0.1918   1.3331       0.9396     0.6704
# 2024-05-24 21:20:52,584 - INFO - machamp.model.callback - sum                 1.3545  32.5998       1.9290     1.4304
# 2024-05-24 21:20:52,660 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │         ▗▄▄▖             ▄▄▀▀▀▀▄▄                          │
# │         ▐  ▝▀▀▄▄▖    ▄▄▀▀        ▀▀▄▄                      │
# │         ▌       ▝▀▀▛▀                ▀▜▄▄▄▄▄▄▄▄▄▄▄▄▄       │ 0.8
# │        ▗▘                                           ▀▀▀▄▄▄▖│
# │        ▞                                                  ▝│
# │        ▌                                                   │
# │       ▐                                                    │
# │       ▞                                    ▄▄▄▞▀▀▀▀▚▄▄▄    │ 0.7
# │       ▌                          ▗▄▄▄▄▄▞▀▀▀            ▀▀▀▚│
# │      ▐                    ▗▄▞▀▀▀▀▘                         │
# │      ▌                ▄▄▞▀▘                                │
# │     ▗▘            ▗▄▀▀                                     │
# │     ▐           ▗▞▘                                        │ 0.6
# │     ▌         ▗▞▘                                          │
# │    ▗▘        ▄▘                                            │
# │    ▞       ▄▀                                              │
# │    ▌   ▄▄▄▀                                                │
# └────────────────────────────────────────────────────────────┘
#  1         2         3         4        5         6         7
#                           ██ intent
#                           ██ slots
# 2024-05-24 21:20:52,674 - INFO - machamp.model.trainer - Saving training state, so that we can use --resume if needed
# 2024-05-24 21:20:52,674 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_7.pt
# 2024-05-24 21:21:02,164 - INFO - machamp.model.trainer - Removing old training state.
# 2024-05-24 21:21:02,164 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_6.pt
# 2024-05-24 21:21:03,720 - INFO - machamp.model.trainer - Epoch 8/20: training
# 100%|███████████████████████████████████████| 1363/1363 [05:49<00:00,  3.90it/s]
# 2024-05-24 21:26:53,557 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-05-24 21:26:53,558 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 9.053053287731686e-05
# 2024-05-24 21:26:53,558 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 9.053053287731686e-05
# 2024-05-24 21:26:53,558 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 3.4401602493380407e-05
# 2024-05-24 21:26:53,558 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-05-24 21:26:53,558 - INFO - machamp.model.trainer - Epoch 8: evaluating on dev
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00,  9.85it/s]
# 2024-05-24 21:26:53,968 - INFO - machamp.model.callback - epoch       : 8/20
# 2024-05-24 21:26:53,969 - INFO - machamp.model.callback - best_epoch  : 4
# 2024-05-24 21:26:53,969 - INFO - machamp.model.callback - max_gpu_mem : 6.7849
# 2024-05-24 21:26:53,969 - INFO - machamp.model.callback - cur_ram     : 1.6558
# 2024-05-24 21:26:53,969 - INFO - machamp.model.callback - time_epoch  : 0:05:50
# 2024-05-24 21:26:53,969 - INFO - machamp.model.callback - time_total  : 0:44:56
# 2024-05-24 21:26:53,969 - INFO - machamp.model.callback -
# 2024-05-24 21:26:53,969 - INFO - machamp.model.callback -                 train_loss dev_loss train_scores dev_scores
# 2024-05-24 21:26:53,970 - INFO - machamp.model.callback - Best (4)
# 2024-05-24 21:26:53,970 - INFO - machamp.model.callback - intent_accuracy     1.5527  14.5033       0.9874     0.8400
# 2024-05-24 21:26:53,970 - INFO - machamp.model.callback - slots_accuracy      0.4400   1.4263       0.8669     0.6543
# 2024-05-24 21:26:53,970 - INFO - machamp.model.callback - sum                 1.9927  15.9296       1.8543     1.4943
# 2024-05-24 21:26:53,971 - INFO - machamp.model.callback - Epoch 8
# 2024-05-24 21:26:53,971 - INFO - machamp.model.callback - intent_accuracy     0.9886  24.7247       0.9915     0.7800
# 2024-05-24 21:26:53,971 - INFO - machamp.model.callback - slots_accuracy      0.1607   1.2198       0.9493     0.6752
# 2024-05-24 21:26:53,971 - INFO - machamp.model.callback - sum                 1.1494  25.9446       1.9408     1.4552
# 2024-05-24 21:26:54,027 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │        ▗▄▖           ▗▄▀▀▀▚▄                               │
# │        ▌ ▝▀▚▄▄    ▄▞▀▘      ▀▚▄▖                           │
# │       ▗▘      ▀▀▞▀             ▝▀▄▄▄▄▄▄▄▄▄▄▄▖              │ 0.8
# │       ▐                                     ▝▀▀▄▄▄ ▄▄▄▄▀▀▀▀│
# │       ▌                                           ▀        │
# │      ▗▘                                                    │
# │      ▐                                                     │
# │      ▞                              ▗▄▄▞▀▀▀▀▄▄▄            │ 0.7
# │      ▌                       ▄▄▄▄▞▀▀▘          ▀▀▀▄▄▄▀▀▀▀▀▀│
# │     ▐                 ▗▄▞▀▀▀▀                              │
# │     ▞              ▄▞▀▘                                    │
# │     ▌          ▗▄▀▀                                        │
# │    ▐          ▄▘                                           │ 0.6
# │    ▞        ▗▞                                             │
# │    ▌       ▞▘                                              │
# │   ▐      ▄▀                                                │
# │   ▐   ▄▄▞                                                  │
# └────────────────────────────────────────────────────────────┘
#          2                4                6                8
#                           ██ intent
#                           ██ slots
# 2024-05-24 21:26:54,048 - INFO - machamp.model.trainer - Saving training state, so that we can use --resume if needed
# 2024-05-24 21:26:54,049 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_8.pt
# 2024-05-24 21:27:03,861 - INFO - machamp.model.trainer - Removing old training state.
# 2024-05-24 21:27:03,861 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_7.pt
# 2024-05-24 21:27:05,375 - INFO - machamp.model.trainer - Epoch 9/20: training
# 100%|███████████████████████████████████████| 1363/1363 [05:50<00:00,  3.88it/s]
# 2024-05-24 21:32:56,369 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-05-24 21:32:56,369 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 8.324673847087379e-05
# ...
# │  ▌    ▗▀                    ▝▄▄▄▄▘                         │
# │  ▌   ▗▘                                                    │ 0.6
# │ ▗▘   ▞                                                     │
# │ ▐   ▞                                                      │
# │ ▐  ▗▘                                                      │
# │ ▐ ▄▘                                                       │
# └────────────────────────────────────────────────────────────┘
#                 5                10                 15
#                           ██ intent
#                           ██ slots
# 2024-05-24 22:21:28,938 - INFO - machamp.model.trainer - Saving training state, so that we can use --resume if needed
# 2024-05-24 22:21:28,938 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_17.pt
# 2024-05-24 22:21:38,709 - INFO - machamp.model.trainer - Removing old training state.
# 2024-05-24 22:21:38,710 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_16.pt
# 2024-05-24 22:21:40,286 - INFO - machamp.model.trainer - Epoch 18/20: training
# 100%|███████████████████████████████████████| 1363/1363 [05:46<00:00,  3.94it/s]
# 2024-05-24 22:27:26,505 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-05-24 22:27:26,505 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 1.7692588812886137e-05
# 2024-05-24 22:27:26,506 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 1.7692588812886137e-05
# 2024-05-24 22:27:26,506 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 6.723183748896733e-06
# 2024-05-24 22:27:26,506 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-05-24 22:27:26,506 - INFO - machamp.model.trainer - Epoch 18: evaluating on dev
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00,  9.74it/s]
# 2024-05-24 22:27:26,920 - INFO - machamp.model.callback - epoch       : 18/20
# 2024-05-24 22:27:26,920 - INFO - machamp.model.callback - best_epoch  : 12
# 2024-05-24 22:27:26,920 - INFO - machamp.model.callback - max_gpu_mem : 6.7849
# 2024-05-24 22:27:26,921 - INFO - machamp.model.callback - cur_ram     : 1.5344
# 2024-05-24 22:27:26,921 - INFO - machamp.model.callback - time_epoch  : 0:05:46
# 2024-05-24 22:27:26,921 - INFO - machamp.model.callback - time_total  : 1:45:29
# 2024-05-24 22:27:26,921 - INFO - machamp.model.callback -
# 2024-05-24 22:27:26,921 - INFO - machamp.model.callback -                 train_loss dev_loss train_scores dev_scores
# 2024-05-24 22:27:26,921 - INFO - machamp.model.callback - Best (12)
# 2024-05-24 22:27:26,921 - INFO - machamp.model.callback - intent_accuracy     0.4582  20.6890       0.9958     0.8500
# 2024-05-24 22:27:26,921 - INFO - machamp.model.callback - slots_accuracy      0.0991   1.3068       0.9688     0.7058
# 2024-05-24 22:27:26,921 - INFO - machamp.model.callback - sum                 0.5573  21.9958       1.9646     1.5558
# 2024-05-24 22:27:26,922 - INFO - machamp.model.callback - Epoch 18
# 2024-05-24 22:27:26,922 - INFO - machamp.model.callback - intent_accuracy     0.1244  32.6727       0.9989     0.8000
# 2024-05-24 22:27:26,922 - INFO - machamp.model.callback - slots_accuracy      0.0610   1.2806       0.9804     0.7251
# 2024-05-24 22:27:26,922 - INFO - machamp.model.callback - sum                 0.1854  33.9533       1.9793     1.5251
# 2024-05-24 22:27:26,998 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │          ▄▖                        ▗▞▀▚                    │
# │   ▞▚▖  ▗▀ ▝▄                      ▛▘   ▚                   │
# │   ▌ ▝▚▄▘    ▚▄▄▄▄                ▐      ▚            ▗▄▛▀▀▀│ 0.8
# │   ▌              ▀▄  ▗▄▟        ▗▘       ▚        ▗▟▀▘     │
# │   ▌                ▀▀▘  ▚       ▞         ▚     ▄▞▘        │
# │  ▗▘                     ▝▖     ▗▘          ▚  ▗▞           │
# │  ▐                       ▐     ▌            ▚▞▘ ▄▄▄▄▄▄▄▄▞▀▀│
# │  ▐             ▄▞▄        ▚  ▄▞  ▗▀▀▀▀▀▀▄▄▖   ▄▀           │ 0.7
# │  ▐          ▗▄▀   ▀▚▄▄▄▄  ▝▄▀    ▞        ▝▀▚▀             │
# │  ▌       ▄▀▀▘           ▀▖      ▞                          │
# │  ▌     ▗▀                ▝▖    ▐                           │
# │  ▌    ▞▘                  ▝▄▄▄▄▘                           │
# │  ▌   ▐                                                     │ 0.6
# │ ▐   ▗▘                                                     │
# │ ▐   ▌                                                      │
# │ ▐  ▞                                                       │
# │ ▞ ▄▘                                                       │
# └────────────────────────────────────────────────────────────┘
#                5               10                15
#                           ██ intent
#                           ██ slots
# 2024-05-24 22:27:26,999 - INFO - machamp.model.trainer - Saving training state, so that we can use --resume if needed
# 2024-05-24 22:27:27,000 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_18.pt
# 2024-05-24 22:27:36,494 - INFO - machamp.model.trainer - Removing old training state.
# 2024-05-24 22:27:36,495 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_17.pt
# 2024-05-24 22:27:38,011 - INFO - machamp.model.trainer - Epoch 19/20: training
# 100%|███████████████████████████████████████| 1363/1363 [05:27<00:00,  4.16it/s]
# 2024-05-24 22:33:05,713 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-05-24 22:33:05,713 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 1.0408794406443074e-05
# 2024-05-24 22:33:05,713 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 1.0408794406443074e-05
# 2024-05-24 22:33:05,713 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 3.9553418744483685e-06
# 2024-05-24 22:33:05,714 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-05-24 22:33:05,714 - INFO - machamp.model.trainer - Epoch 19: evaluating on dev
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 26.26it/s]
# 2024-05-24 22:33:05,869 - INFO - machamp.model.callback - epoch       : 19/20
# 2024-05-24 22:33:05,869 - INFO - machamp.model.callback - best_epoch  : 12
# 2024-05-24 22:33:05,870 - INFO - machamp.model.callback - max_gpu_mem : 6.7849
# 2024-05-24 22:33:05,870 - INFO - machamp.model.callback - cur_ram     : 1.5465
# 2024-05-24 22:33:05,870 - INFO - machamp.model.callback - time_epoch  : 0:05:27
# 2024-05-24 22:33:05,870 - INFO - machamp.model.callback - time_total  : 1:51:08
# 2024-05-24 22:33:05,870 - INFO - machamp.model.callback -
# 2024-05-24 22:33:05,870 - INFO - machamp.model.callback -                 train_loss dev_loss train_scores dev_scores
# 2024-05-24 22:33:05,870 - INFO - machamp.model.callback - Best (12)
# 2024-05-24 22:33:05,870 - INFO - machamp.model.callback - intent_accuracy     0.4582  20.6890       0.9958     0.8500
# 2024-05-24 22:33:05,870 - INFO - machamp.model.callback - slots_accuracy      0.0991   1.3068       0.9688     0.7058
# 2024-05-24 22:33:05,870 - INFO - machamp.model.callback - sum                 0.5573  21.9958       1.9646     1.5558
# 2024-05-24 22:33:05,871 - INFO - machamp.model.callback - Epoch 19
# 2024-05-24 22:33:05,871 - INFO - machamp.model.callback - intent_accuracy     0.0788  30.1313       0.9990     0.7900
# 2024-05-24 22:33:05,871 - INFO - machamp.model.callback - slots_accuracy      0.0573   1.3471       0.9814     0.7267
# 2024-05-24 22:33:05,871 - INFO - machamp.model.callback - sum                 0.1361  31.4784       1.9804     1.5167
# 2024-05-24 22:33:05,905 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │         ▗▖                       ▗▞▀▖                      │
# │   ▛▄   ▞▘▝▚                     ▛▘  ▝▖                     │
# │   ▌ ▀▄▞    ▚▄▄▄▄               ▐     ▝▖           ▗▄▀▀▀▀▄▄▄│ 0.8
# │   ▌             ▀▄  ▗▄▚        ▌      ▝▖       ▗▟▀▘        │
# │  ▐                ▀▀▘ ▝▖      ▞        ▝▖    ▗▞▘           │
# │  ▐                     ▚     ▗▘         ▝▖  ▞▘             │
# │  ▐                      ▌    ▞           ▝▄▀ ▄▄▄▄▄▄▄▄▀▀▀▀▀▀│
# │  ▐            ▗▞▄       ▝▖ ▗▞▘ ▗▀▀▀▀▀▀▄▄   ▗▞              │ 0.7
# │  ▌         ▗▄▀▘  ▀▚▄▄▄▄  ▚▞▘   ▞        ▀▀▞▘               │
# │  ▌      ▗▞▀▘           ▚      ▞                            │
# │  ▌     ▞▘               ▚    ▗▘                            │
# │  ▌   ▗▞                  ▚▄▄▄▌                             │
# │ ▐    ▌                                                     │ 0.6
# │ ▐   ▐                                                      │
# │ ▐  ▗▘                                                      │
# │ ▐  ▞                                                       │
# │ ▌ ▟                                                        │
# └────────────────────────────────────────────────────────────┘
#               5               10              15
#                           ██ intent
#                           ██ slots
# 2024-05-24 22:33:05,906 - INFO - machamp.model.trainer - Saving training state, so that we can use --resume if needed
# 2024-05-24 22:33:05,907 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_19.pt
# 2024-05-24 22:33:10,022 - INFO - machamp.model.trainer - Removing old training state.
# 2024-05-24 22:33:10,022 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_18.pt
# 2024-05-24 22:33:10,624 - INFO - machamp.model.trainer - Epoch 20/20: training
# 100%|███████████████████████████████████████| 1363/1363 [02:45<00:00,  8.24it/s]
# 2024-05-24 22:35:56,124 - INFO - machamp.modules.allennlp.slanted_triangular - Learning rates for each group:
#
# 2024-05-24 22:35:56,125 - INFO - machamp.modules.allennlp.slanted_triangular - 0: 3.125e-06
# 2024-05-24 22:35:56,125 - INFO - machamp.modules.allennlp.slanted_triangular - 1: 3.125e-06
# 2024-05-24 22:35:56,125 - INFO - machamp.modules.allennlp.slanted_triangular - 2: 1.1875e-06
# 2024-05-24 22:35:56,125 - INFO - machamp.modules.allennlp.slanted_triangular - Gradual unfreezing finished. Training all layers.
# 2024-05-24 22:35:56,125 - INFO - machamp.model.trainer - Epoch 20: evaluating on dev
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 26.19it/s]
# 2024-05-24 22:35:56,282 - INFO - machamp.model.callback - epoch       : 20/20
# 2024-05-24 22:35:56,282 - INFO - machamp.model.callback - best_epoch  : 12
# 2024-05-24 22:35:56,282 - INFO - machamp.model.callback - max_gpu_mem : 6.7849
# 2024-05-24 22:35:56,282 - INFO - machamp.model.callback - cur_ram     : 1.5814
# 2024-05-24 22:35:56,282 - INFO - machamp.model.callback - time_epoch  : 0:02:45
# 2024-05-24 22:35:56,282 - INFO - machamp.model.callback - time_total  : 1:53:59
# 2024-05-24 22:35:56,283 - INFO - machamp.model.callback -
# 2024-05-24 22:35:56,283 - INFO - machamp.model.callback -                 train_loss dev_loss train_scores dev_scores
# 2024-05-24 22:35:56,283 - INFO - machamp.model.callback - Best (12)
# 2024-05-24 22:35:56,283 - INFO - machamp.model.callback - intent_accuracy     0.4582  20.6890       0.9958     0.8500
# 2024-05-24 22:35:56,283 - INFO - machamp.model.callback - slots_accuracy      0.0991   1.3068       0.9688     0.7058
# 2024-05-24 22:35:56,283 - INFO - machamp.model.callback - sum                 0.5573  21.9958       1.9646     1.5558
# 2024-05-24 22:35:56,283 - INFO - machamp.model.callback - Epoch 20
# 2024-05-24 22:35:56,284 - INFO - machamp.model.callback - intent_accuracy     0.0596  29.9579       0.9994     0.8000
# 2024-05-24 22:35:56,284 - INFO - machamp.model.callback - slots_accuracy      0.0555   1.3780       0.9818     0.7315
# 2024-05-24 22:35:56,284 - INFO - machamp.model.callback - sum                 0.1151  31.3359       1.9812     1.5315
# 2024-05-24 22:35:56,318 - INFO - machamp.model.callback -
#                 Dev scores (y) over epochs (x)
# ┌────────────────────────────────────────────────────────────┐
# │         ▄                      ▗▞▀▖                        │
# │   ▛▄  ▗▀ ▀▖                   ▞▘  ▝▖                       │
# │   ▌ ▚▄▘   ▝▄▄▄▄              ▗▘    ▝▖           ▄▛▀▀▀▄▄▄▄▄▟│ 0.8
# │  ▐             ▀▄  ▗▄▌       ▞      ▝▖       ▄▀▀           │
# │  ▐               ▀▀▘ ▐      ▗▘       ▝▖    ▄▀              │
# │  ▐                    ▌     ▞         ▝  ▗▞             ▗▄▄│
# │  ▐                    ▝▖   ▗▘          ▚▞▘ ▄▄▄▄▄▄▄▀▀▀▀▀▀▘  │
# │  ▌           ▗▞▄       ▚  ▄▘  ▞▀▀▀▀▀▄▄   ▄▀                │ 0.7
# │  ▌         ▄▞▘  ▀▚▄▄▄▖ ▝▄▀   ▐        ▀▚▛                  │
# │  ▌      ▄▀▀          ▝▖     ▗▘                             │
# │  ▌    ▗▞              ▝▖    ▌                              │
# │ ▐    ▄▘                ▝▄▄▄▞                               │
# │ ▐   ▗▘                                                     │ 0.6
# │ ▐   ▞                                                      │
# │ ▐  ▐                                                       │
# │ ▞ ▗▘                                                       │
# │ ▌▗▞                                                        │
# └────────────────────────────────────────────────────────────┘
#              5              10              15             20
#                           ██ intent
#                           ██ slots
# 2024-05-24 22:35:56,318 - INFO - machamp.model.callback - Best performance obtained in epoch 12 linking model model_12.pt as logs/nlu_en/2024.05.24_20.40.00/model.pt.
# 2024-05-24 22:35:56,319 - INFO - machamp.model.trainer - Saving training state, so that we can use --resume if needed
# 2024-05-24 22:35:56,319 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_20.pt
# 2024-05-24 22:36:00,379 - INFO - machamp.model.trainer - Removing old training state.
# 2024-05-24 22:36:00,379 - INFO - machamp.model.trainer - Path: logs/nlu_en/2024.05.24_20.40.00/train_state_epoch_19.pt
# 2024-05-24 22:36:01,531 - INFO - machamp.model.trainer - Predicting on dev set
# 2024-05-24 22:36:04,217 - INFO - machamp.data.machamp_dataset - Reading /home/afkhabirzyanova_3/jupyterhub_slurm/machamp/data/xSID-tat/final_tat.valid.conll...
# 2024-05-24 22:36:04,299 - INFO - machamp.readers.read_sequence - Stats NLU (/home/afkhabirzyanova_3/jupyterhub_slurm/machamp/data/xSID-tat/final_tat.valid.conll):
# 2024-05-24 22:36:04,300 - INFO - machamp.readers.read_sequence - Lines:      100
# 2024-05-24 22:36:04,300 - INFO - machamp.readers.read_sequence - Words:      622
# 2024-05-24 22:36:04,301 - INFO - machamp.readers.read_sequence - Subwords:   1,438
# 2024-05-24 22:36:04,301 - INFO - machamp.readers.read_sequence - Unks:       0
# 2024-05-24 22:36:04,301 - INFO - machamp.readers.read_sequence - Pre-splits: 0
# 2024-05-24 22:36:04,301 - INFO - machamp.data.machamp_dataset - Done reading /home/afkhabirzyanova_3/jupyterhub_slurm/machamp/data/xSID-tat/final_tat.valid.conll (0.0s)
#
# 2024-05-24 22:36:04,301 - ERROR - STDERR - /home/afkhabirzyanova_3/.local/lib/python3.10/site-packages/torch/utils/data/sampler.py:64: UserWarning: `data_source` argument is not used and will be removed in 2.2.0.You may still have custom implementation that utilizes it.
# 2024-05-24 22:36:04,301 - ERROR - STDERR -   warnings.warn("`data_source` argument is not used and will be removed in 2.2.0."
# 2024-05-24 22:36:04,512 - INFO - machamp.utils.myutils - intent_accuracy : 0.8500
# 2024-05-24 22:36:04,512 - INFO - machamp.utils.myutils - slots_accuracy  : 0.7058
# 2024-05-24 22:36:04,512 - INFO - machamp.utils.myutils - sum             : 1.5558
# 2024-05-24 22:36:04,514 - INFO - machamp.utils.myutils -

# %%
# %mkdir predictions_en

# %%
# %pwd
# Out:
# '/home/afkhabirzyanova_3/jupyterhub_slurm/machamp'

# %%
# !python3 predict.py logs/nlu_en/2024.05.24_20.40.00/model_12.pt data/xSID-tat/final_tat.test.conll predictions_en/nlu.xsid.out --device 0
# Out:
# /opt/software/python/jupyterhub2/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2024-05-24 22:46:04,867 - INFO - __main__ - cmd: predict.py logs/nlu_en/2024.05.24_20.40.00/model_12.pt data/xSID-tat/final_tat.test.conll predictions_en/nlu.xsid.out --device 0
#
# 2024-05-24 22:46:04,868 - INFO - __main__ - loading model...
# 2024-05-24 22:46:06,629 - INFO - __main__ - predicting on data/xSID-tat/final_tat.test.conll, saving on predictions_en/nlu.xsid.out
# 2024-05-24 22:46:08,494 - INFO - machamp.data.machamp_dataset - Reading data/xSID-tat/final_tat.test.conll...
# 2024-05-24 22:46:08,902 - INFO - machamp.readers.read_sequence - Stats NLU (data/xSID-tat/final_tat.test.conll):
# 2024-05-24 22:46:08,903 - INFO - machamp.readers.read_sequence - Lines:      536
# 2024-05-24 22:46:08,903 - INFO - machamp.readers.read_sequence - Words:      3,208
# 2024-05-24 22:46:08,903 - INFO - machamp.readers.read_sequence - Subwords:   7,276
# 2024-05-24 22:46:08,903 - INFO - machamp.readers.read_sequence - Unks:       0
# 2024-05-24 22:46:08,903 - INFO - machamp.readers.read_sequence - Pre-splits: 0
# 2024-05-24 22:46:08,903 - INFO - machamp.data.machamp_dataset - Done reading data/xSID-tat/final_tat.test.conll (0.0s)
#
# /home/afkhabirzyanova_3/.local/lib/python3.10/site-packages/torch/utils/data/sampler.py:64: UserWarning: `data_source` argument is not used and will be removed in 2.2.0.You may still have custom implementation that utilizes it.
#   warnings.warn("`data_source` argument is not used and will be removed in 2.2.0."
# 2024-05-24 22:46:19,321 - INFO - machamp.utils.myutils - intent_accuracy : 0.8315
# 2024-05-24 22:46:19,322 - INFO - machamp.utils.myutils - slots_accuracy  : 0.7008
# 2024-05-24 22:46:19,322 - INFO - machamp.utils.myutils - sum             : 1.5322
# 2024-05-24 22:46:19,322 - INFO - machamp.utils.myutils -
